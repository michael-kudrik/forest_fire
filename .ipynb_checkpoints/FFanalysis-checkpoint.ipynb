# %%
#Import Libraries
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Insert data into Pandas Dataframe
df = pd.read_csv('forestfires.csv', na_values = ":", usecols = ['FFMC', 'DMC', 'temp', 'RH'])

#Verify if the dataframe is correct
df.head()

#Describe the data
df.describe()
# Out:
#              FFMC         DMC        temp          RH
# count  517.000000  517.000000  517.000000  517.000000
# mean    90.644681  110.872340   18.889168   44.288201
# std      5.520111   64.046482    5.806625   16.317469
# min     18.700000    1.100000    2.200000   15.000000
# 25%     90.200000   68.600000   15.500000   33.000000
# 50%     91.600000  108.300000   19.300000   42.000000
# 75%     92.900000  142.400000   22.800000   53.000000
# max     96.200000  291.300000   33.300000  100.000000

# %%
#Intitilize Seaborn for our graphs
sns.set(style="whitegrid")

# Create figure with figsize
plt.figure(figsize=(16, 10))

def evaluate_correlation(arg1, arg2, sub_pos):
    
    correlation = df[arg1].corr(df[arg2])

    plt.subplot(sub_pos)

    sns.regplot(x=arg1, y=arg2, data=df, scatter_kws={'alpha':0.7},line_kws={'color':'green'})

    plt.title(f'{arg1} vs {arg2}\nCorrelation: {correlation:.4f}')
    plt.xlabel(arg1)
    plt.ylabel(arg2)
